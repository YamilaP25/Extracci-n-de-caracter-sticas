# %% [markdown]
# <a href="https://colab.research.google.com/github/YamilaP25/Extracci-n-de-caracter-sticas/blob/main/Actividad_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Instalamos librería para análisis de variables categóricas
# %pip install funpymodeling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from funpymodeling.exploratory import freq_tbl

# %%
#cargar archivo csv desde equipo
from google.colab import files
files.upload()

# %%
df = pd.read_excel('microretailer_mit_lift_lab.xlsx')
df.head(5)

# %%
df1 = df.iloc[ : , [3, 48, 9, 10, 11, 12, 15, 18, 19, 23, 24, 25, 26, 27, 30, 32, 34, 35, 36, 47]]
df1.head(5)
# Out:
#             _updated_by 33_credit_to_customers  \
# 0  Salomon Abdala Perez                     no
# 1  Salomon Abdala Perez                     no
# 2  Salomon Abdala Perez                    yes
# 3  Salomon Abdala Perez                     no
# 4  Salomon Abdala Perez                    yes
#
#                 232_type_of_store  \
# 0                          Tailor
# 1  Grocery store (aka. nanostore)
# 2  Grocery store (aka. nanostore)
# 3  Grocery store (aka. nanostore)
# 4  Grocery store (aka. nanostore)
#
#   108_does_the_micro_retailer_has_a_barred_window_  \
# 0                                              yes
# 1                                               no
# 2                                              yes
# 3                                               no
# 4                                              yes
#
#   99_does_the_micro_retailer_exhibits_products_outside_  \
# 0                                                 no
# ...

# %%
#Reemplazamos los valores nulos del dataFrame con 'bfill'
valores_nulos = df1.isnull().sum()
print(valores_nulos)
df2 = df1.fillna(method = 'bfill')
df2 = df2.fillna(method = 'ffill')
valores_nulos = df2.isnull().sum()
print('\n', valores_nulos)

# %% [markdown]
# #1. Variable _updated_by

# %%
updated_by = freq_tbl(df2['_updated_by'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro = updated_by[updated_by['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('_updated_by')
Filtro_index = Filtro_index.drop(Filtro_index.columns[1:], axis=1)
Filtro_index
# Out:
#                                    frequency
# _updated_by
# Salomon Abdala Perez                      20
# Ángel Francisco Altamirano Campos         16
# José Zapata                               14
# Emilio Garza                              13
# Benjamin Barbosa                          13
# Pedro Contreras                           12
# Eduardo Zárate                             9
# Alejandro Matias                           8
# Harry Hernández                            7
# Francisco Adán                             7
# Hiram Jiménez                              6
# Ismael López                               6
# Mauro Munguía                              4
# Alan Bravo                                 4
# Sandra Carreón                             4
# Jorge Mason                                3
# Jesús Herrera                              3
# Ricardo Galindo Bulos                      3
# Yael Loeza                                 2
# ...

# %%
#Realizamos grafico de barras del dataframe filtrado
import matplotlib.pyplot as plt

Filtro_index.plot(kind = 'bar', width=1, figsize=(8,4))
plt.title('Herramientas de relación con updated by')
plt.xlabel('Tipo de updated by')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #2. Variable 228_store_name

# %%
credit_to_customers = freq_tbl(df2['33_credit_to_customers'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= credit_to_customers[credit_to_customers['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('33_credit_to_customers')
Filtro_index
# Out:
#                         frequency  percentage  cumulative_perc
# 33_credit_to_customers
# no                            135    0.789474         0.789474
# yes                            36    0.210526         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# #3. Variable 232_type_of_store

# %%
type_of_store = freq_tbl(df2['232_type_of_store'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= type_of_store[type_of_store['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('232_type_of_store')
Filtro_index = Filtro_index.drop(Filtro_index.columns[1:], axis=1)
Filtro_index
# Out:
#                                  frequency
# 232_type_of_store
# Grocery store (aka. nanostore)          52
# Micro-restaurant (aka. fondita)         31
# Dairy products                          10
# Cafeteria                                6
# Butcher shop                             6
# Produce (fruits & vegetables)            4
# Handmade products                        2
# Papelería                                2
# objetos                                  2
# Ferretería                               2

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(8,4))
plt.title('Herramientas de relación con type_of_store')
plt.xlabel('type_of_store')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #4. Variable 108_does_the_micro_retailer_has_a_barred_window_

# %%
micro_retailer = freq_tbl(df2['108_does_the_micro_retailer_has_a_barred_window_'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= micro_retailer[micro_retailer['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('108_does_the_micro_retailer_has_a_barred_window_')
Filtro_index
# Out:
#                                                   frequency  percentage  \
# 108_does_the_micro_retailer_has_a_barred_window_
# no                                                      124    0.725146
# yes                                                      47    0.274854
#
#                                                   cumulative_perc
# 108_does_the_micro_retailer_has_a_barred_window_
# no                                                       0.725146
# yes                                                      1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# #5. Variable 99_does_the_micro_retailer_exhibits_products_outside_

# %%
micro_retailer_outside = freq_tbl(df2['99_does_the_micro_retailer_exhibits_products_outside_'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= micro_retailer_outside[micro_retailer_outside['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('99_does_the_micro_retailer_exhibits_products_outside_')
Filtro_index
# Out:
#                                                     frequency  percentage  \
# 99_does_the_micro_retailer_exhibits_products_ou...
# no                                                        120    0.701754
# yes                                                        51    0.298246
#
#                                                     cumulative_perc
# 99_does_the_micro_retailer_exhibits_products_ou...
# no                                                         0.701754
# yes                                                        1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# #6. Variable 102_does_the_micro_retailer_sells_fresh_products_

# %%
micro_retailer_fresh_product = freq_tbl(df2['102_does_the_micro_retailer_sells_fresh_products_'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= micro_retailer_fresh_product[micro_retailer_fresh_product['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('102_does_the_micro_retailer_sells_fresh_products_')
Filtro_index
# Out:
#                                                    frequency  percentage  \
# 102_does_the_micro_retailer_sells_fresh_products_
# no                                                       105    0.614035
# yes                                                       66    0.385965
#
#                                                    cumulative_perc
# 102_does_the_micro_retailer_sells_fresh_products_
# no                                                        0.614035
# yes                                                       1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# #7. Variable 184_store_devices

# %%
store_devices = freq_tbl(df2['184_store_devices'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= store_devices[store_devices['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('184_store_devices')
Filtro_index = Filtro_index.drop(Filtro_index.columns[1:], axis=1)
Filtro_index
# Out:
#                                                     frequency
# 184_store_devices
# Smartphone                                                 52
# Analog cash register                                       16
# POS system (i.e. computer + bar code scanner + ...          9
# POS system (i.e. computer + bar code scanner + ...          9
# Analog cash register,Smartphone                             8
# Security cameras,Smartphone                                 7
# Dataphone (i.e. card payments),Security cameras...          5
# Security cameras                                            5
# Analog cash register,Security cameras,Smartphone            5
# Dataphone (i.e. card payments)                              4
# POS system (i.e. computer + bar code scanner + ...          4
# Analog cash register,Security cameras                       4
# Analog cash register,POS system (i.e. computer ...          4
# Dataphone (i.e. card payments),Security cameras             3
# ...

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(8,4))
plt.title('Herramientas de relación con store_devices')
plt.xlabel('store_devices')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #8. Variable hola_somos_estudiantes_del_tec_de_monterrey_estamos_realiz

# %%
estudiantes_tec = freq_tbl(df2['hola_somos_estudiantes_del_tec_de_monterrey_estamos_realiz'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= estudiantes_tec[estudiantes_tec['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('hola_somos_estudiantes_del_tec_de_monterrey_estamos_realiz')
Filtro_index
# Out:
#                                                     frequency  percentage  \
# hola_somos_estudiantes_del_tec_de_monterrey_est...
# yes                                                       113    0.660819
# no                                                         58    0.339181
#
#                                                     cumulative_perc
# hola_somos_estudiantes_del_tec_de_monterrey_est...
# yes                                                        0.660819
# no                                                         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# #9. Variable le_comento_que_toda_esta_informacin_es_confidencial

# %%
informacion_confidencial = freq_tbl(df2['le_comento_que_toda_esta_informacin_es_confidencial'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= informacion_confidencial[informacion_confidencial['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('le_comento_que_toda_esta_informacin_es_confidencial')
Filtro_index
# Out:
#                                                     frequency  percentage  \
# le_comento_que_toda_esta_informacin_es_confiden...
# yes                                                       164    0.959064
# no                                                          7    0.040936
#
#                                                     cumulative_perc
# le_comento_que_toda_esta_informacin_es_confiden...
# yes                                                        0.959064
# no                                                         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# #10. Variable 5_change_store_space_last_year

# %%
store_space = freq_tbl(df2['5_change_store_space_last_year'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= store_space[store_space['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('5_change_store_space_last_year')
Filtro_index = Filtro_index.drop(Filtro_index.columns[1:], axis=1)
Filtro_index
# Out:
#                                 frequency
# 5_change_store_space_last_year
# No cambió                             122
# Aumentó 25%                            16
# Disminuyó 15%                          15
# Aumentó 50% o más                       9
# Aumentó 15%                             4
# Disminuyó 50% o más                     3
# Disminuyó 25%                           2

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(8,4))
plt.title('Herramientas de relación con store space')
plt.xlabel('store_space')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #11. Variable 6_change_employees_average_salary_last_year

# %%
employees_average = freq_tbl(df2['6_change_employees_average_salary_last_year'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= employees_average[employees_average['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('6_change_employees_average_salary_last_year')
Filtro_index = Filtro_index.drop(Filtro_index.columns[1:], axis=1)
Filtro_index
# Out:
#                                              frequency
# 6_change_employees_average_salary_last_year
# No cambió                                           97
# Aumentó 15%                                         23
# Aumentó 50% o más                                   12
# No hay empleándosela                                10
# 40                                                   9
# Disminuyó 15%                                        8
# Disminuyó 25%                                        4
# Aumentó 25%                                          4
# 0                                                    2

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(8,4))
plt.title('Herramientas de relación con employees average')
plt.xlabel('employees_average')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #12. Variable 20_reviews_finances_monthly

# %%
finances_monthly = freq_tbl(df2['20_reviews_finances_monthly'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= finances_monthly[finances_monthly['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('20_reviews_finances_monthly')
Filtro_index
# Out:
#                              frequency  percentage  cumulative_perc
# 20_reviews_finances_monthly
# yes                                127     0.74269          0.74269
# no                                  44     0.25731          1.00000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# #13. Variable 49_inventory_records

# %%
inventory_records = freq_tbl(df2['49_inventory_records'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= inventory_records[inventory_records['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('49_inventory_records')
Filtro_index = Filtro_index.drop(Filtro_index.columns[1:], axis=1)
Filtro_index
# Out:
#                                           frequency
# 49_inventory_records
# En papel                                         65
# En Excel                                         31
# Software especializado + computadora             29
# No lo hago                                       24
# En Excel,En papel                                17
# Aplicación móvil (i.e. App) + smartphone          2

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(8,4))
plt.title('Herramientas de relación con inventory records')
plt.xlabel('inventory_records')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #14. Variable 18_sales_records

# %%
sales_records = freq_tbl(df2['18_sales_records'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= sales_records[sales_records['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('18_sales_records')
Filtro_index = Filtro_index.drop(Filtro_index.columns[1:], axis=1)
Filtro_index
# Out:
#                                                     frequency
# 18_sales_records
# En papel                                                   67
# Software especializado + computadora                       26
# No lo hago                                                 24
# En Excel                                                   21
# En Excel,En papel                                          12
# Caja registradora (análoga)                                 6
# Aplicación móvil (i.e. App) + smartphone,Caja r...          5
# Caja registradora (análoga),En Excel,En papel               3

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(8,4))
plt.title('Herramientas de relación con sales records')
plt.xlabel('sales_records')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #15. Variable 19_tax_id

# %%
tax_id = freq_tbl(df2['19_tax_id'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= tax_id[tax_id['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('19_tax_id')
Filtro_index
# Out:
#            frequency  percentage  cumulative_perc
# 19_tax_id
# yes              113    0.660819         0.660819
# no                58    0.339181         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# #16. Variable 310_burnout

# %%
burnout = freq_tbl(df2['310_burnout'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= burnout[burnout['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('310_burnout')
Filtro_index
# Out:
#              frequency  percentage  cumulative_perc
# 310_burnout
# no                  98    0.573099         0.573099
# yes                 73    0.426901         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# #17. Variable 186_internet_connection

# %%
internet_connection = freq_tbl(df2['186_internet_connection'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= internet_connection[internet_connection['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('186_internet_connection')
Filtro_index
# Out:
#                          frequency  percentage  cumulative_perc
# 186_internet_connection
# yes                            123    0.719298         0.719298
# no                              48    0.280702         1.000000

# %%
#Realizamos grafico de pastel del dataframe filtrado
Filtro_index["frequency"].plot(kind='pie', figsize=(10,5), shadow=True, autopct="%0.1f %%")
# Out:
# <Axes: ylabel='frequency'>

# %% [markdown]
# #18. Variable 210_sales_channels

# %%
sales_channels = freq_tbl(df2['210_sales_channels'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= sales_channels[sales_channels['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('210_sales_channels')
Filtro_index = Filtro_index.drop(Filtro_index.columns[1:], axis=1)
Filtro_index
# Out:
#                                                     frequency
# 210_sales_channels
# Redes sociales (e.g. Facebook, Instagram),WhatsApp         26
# WhatsApp                                                   22
# Redes sociales (e.g. Facebook, Instagram)                  20
# Llamada a Teléfono fijo                                    12
# conocidos paquetes cerrados                                10
# Llamada a Teléfono celular,WhatsApp                         8
# Llamada a Teléfono celular                                  7
# Página web propia,WhatsApp                                  7
# Llamada a Teléfono celular,Redes sociales (e.g....          7
# Página web propia,Redes sociales (e.g. Facebook...          7
# Llamada a Teléfono fijo,Redes sociales (e.g. Fa...          6
# Página web propia                                           5
# Ninguno                                                     5
# Llamada a Teléfono celular,Página web propia,Re...          4
# ...

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(8,4))
plt.title('Herramientas de relación con sales channels')
plt.xlabel('sales_channels')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #19. Variable 189_payment_methods

# %%
payment_methods = freq_tbl(df2['189_payment_methods'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= payment_methods[payment_methods['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('189_payment_methods')
Filtro_index = Filtro_index.drop(Filtro_index.columns[1:], axis=1)
Filtro_index
# Out:
#                                                     frequency
# 189_payment_methods
# Efectivo                                                   64
# Efectivo,Tarjeta de débito y/o crédito,Transfer...         49
# Efectivo,Tarjeta de débito y/o crédito                     35
# Efectivo,Transferencia interbancaria                       20

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(8,4))
plt.title('Herramientas de relación con payment_methods')
plt.xlabel('payment_methods')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #20. Variable 214_customer_relationship_tools

# %%
relationship_tools = freq_tbl(df2['214_customer_relationship_tools'])
#Obtengo un filtro de los valores más reelevantes de la variables categórica seleccionada
Filtro= relationship_tools[relationship_tools['frequency']>1]
#Ajusto el indice de mi dataframe
Filtro_index= Filtro.set_index('214_customer_relationship_tools')
Filtro_index = Filtro_index.drop(Filtro_index.columns[1:], axis=1)
Filtro_index
# Out:
#                                  frequency
# 214_customer_relationship_tools
# Redes sociales                          57
# Ninguna                                 44
# Aplicación móvil                        31
# Aplicación móvil,Redes sociales         22
# Cuaderno                                 9

# %%
#Realizamos grafico de barras del dataframe filtrado
Filtro_index.plot(kind = 'bar', width=1, figsize=(8,4))
plt.title('Herramientas de relación con relationship tools')
plt.xlabel('relationship_tools')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
